# %% [markdown]
# # Extract results held in Molpro variables

# %%
from pymolpro import Project

# %%
p=Project("molpro_variables")
p.write_input("""
do i=1,73
x(i)=i*10, cosine(i)=cos(x(i)), sine(i)=sin(x(i))
enddo
put,xml
""")
p.run(wait=True, force=True)
assert p.status=='completed' and not p.errors()
# Out:
# Traceback (most recent call last):
#
#   File ~\anaconda3\envs\pymolpro\Lib\site-packages\IPython\core\interactiveshell.py:3433 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In [19], line 9
#     assert p.status=='completed' and not p.errors()
#
#   File ~\anaconda3\envs\pymolpro\Lib\site-packages\pymolpro\project.py:64 in errors
#     errors = self.select('//error')
#
#   File ~\anaconda3\envs\pymolpro\Lib\site-packages\pysjef\project.py:82 in select
#     self.parse()
#
#   File ~\anaconda3\envs\pymolpro\Lib\site-packages\pysjef\project.py:266 in parse
#     xml_tree = etree.fromstring(xml_string, parser=RootXml.parser)
#
#   File src/lxml/etree.pyx:3254 in lxml.etree.fromstring
#
#   File src/lxml/parser.pxi:1913 in lxml.etree._parseMemoryDocument
#
#   File src/lxml/parser.pxi:1793 in lxml.etree._parseDoc
#
#   File src/lxml/parser.pxi:1082 in lxml.etree._BaseParser._parseUnicodeDoc
#
#   File src/lxml/parser.pxi:615 in lxml.etree._ParserContext._handleParseResultDoc
#
#   File src/lxml/parser.pxi:725 in lxml.etree._handleParseResult
#
#   File src/lxml/parser.pxi:654 in lxml.etree._raiseParseError
#
#   File <string>:16
# XMLSyntaxError: Char 0x0 out of allowed range, line 16, column 46

# %%
values={}
for name in ['x','sine','cosine']:
    # values[name]=[float(v.text) for v in p.xpath('//variable[@name="'+name.upper()+'"]/value')]
    values[name]=p.variable(name)

# %%
import matplotlib.pyplot as plt
plt.plot(values['x'],values['sine'],values['x'],values['cosine'])
plt.legend(['Sine','Cosine']);
